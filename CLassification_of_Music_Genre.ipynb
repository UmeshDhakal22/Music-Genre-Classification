# %% [markdown]
# <a href="https://colab.research.google.com/github/Anugyak/Music-Genre-Classification/blob/main/CLassification_of_Music_Genre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import librosa, librosa.display
import matplotlib.pyplot as plt

# %%
demo_file = "classical.00028.wav"

# %%
# load audio file with librosa
signal, sample_rate = librosa.load(demo_file)

# %%
print(signal)
# Out:
# [-0.01916504 -0.04623413 -0.0696106  ... -0.0083313   0.01409912
#   0.03713989]

# %%
print(sample_rate)
# Out:
# 22050

# %%
FIG_SIZE = (12,6)

# %%
# WAVEFORM
plt.figure(figsize=FIG_SIZE)
librosa.display.waveplot(signal, sample_rate, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
# Out:
# Text(0.5, 1.0, 'Waveform')

# %%
# Fourier Transform (FFT) - Frequency Domain
fft = np.fft.fft(signal)

# %%
# Calculate the Magnitude (abs values on complex numbers)
spectrum = np.abs(fft)

# %%
# Create the Frequency variable
f = np.linspace(0, sample_rate, len(spectrum))

# %%
# Plot Spectrum
plt.figure(figsize=FIG_SIZE)
plt.plot(f, spectrum, alpha=0.5)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Power Spectrum')

# %%
# Take half of the spectrum and frequency
left_spectrum = spectrum[:int(len(spectrum)/2)]
left_f = f[:int(len(spectrum)/2)]

# %%
# Plot Spectrum
plt.figure(figsize=FIG_SIZE)
plt.plot(left_f, left_spectrum, alpha=0.5)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Power Spectrum')

# %%
# Spectrogram (STFT)
hop_length = 512 # num. of samples
n_fft = 2048 # num. of samples for window

# %%
# Perform STFT
stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)

# %%
# Calculate the Magnitude (abs values on complex numbers)
spectrogram = np.abs(stft)

# %%
# Plot the Spectrogram
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.title("Spectrogram")
# Out:
# Text(0.5, 1.0, 'Spectrogram')

# %%
# Apply Logarithm to get values in Decibels
log_spectrogram = librosa.amplitude_to_db(spectrogram)

# %%
# Plot the Spectrogram in Decibels
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(log_spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format="%+2.0f dB")
plt.title("Spectrogram (dB)")
# Out:
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
# MFCCs (we use 13 MFCCs)
MFCCs = librosa.feature.mfcc(signal, sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=13)

# %%
# Plot MFCCs
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(MFCCs, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.title("MFCCs")
# Out:
# Text(0.5, 1.0, 'MFCCs')

# %%
import json
import os
import math
import librosa
import numpy as np

# %%
DATASET_PATH = "/content/drive/MyDrive/genres_original"
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
        
if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00012.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00012.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00012.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00012.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00012.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00009.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00002.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00006.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00010.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00011.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00007.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00015.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00025.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00024.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00026.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00022.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00018.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:3
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:4
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:5
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:6
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:7
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:8
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:9
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav, segment:10
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00062.wav, segment:1
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00062.wav, segment:2
# /content/drive/MyDrive/genres_original/hiphop/hiphop.00062.wav, segment:3
# ...
# /content/drive/MyDrive/genres_original/metal/metal.00075.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00065.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00079.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00080.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav, segment:10
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:1
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:2
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:3
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:4
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:5
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:6
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:7
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:8
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:9
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav, segment:10

# %%
import json
#import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
DATA_PATH = "/content/data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3,3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3,3), strides=(2, 2), padding='same'))
    model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.Dense(32, activation='relu'))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model



def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 11, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 64, 6, 32)        0
#  )
#
#  batch_normalization (BatchN  (None, 64, 6, 32)        128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 62, 4, 32)         9248
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 2, 32)        0
#  2D)
#
#  dropout (Dropout)           (None, 31, 2, 32)         0
#
#  batch_normalization_1 (Batc  (None, 31, 2, 32)        128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 30, 1, 32)         4128
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 1, 32)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 15, 1, 32)         0
#
#  batch_normalization_2 (Batc  (None, 15, 1, 32)        128
#  hNormalization)
#
#  flatten (Flatten)           (None, 480)               0
#
#  dense (Dense)               (None, 64)                30784
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 47,274
# Trainable params: 47,082
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/50
# 188/188 [==============================] - 20s 94ms/step - loss: 1.9271 - accuracy: 0.3062 - val_loss: 1.4565 - val_accuracy: 0.4653
# Epoch 2/50
# 188/188 [==============================] - 15s 81ms/step - loss: 1.5174 - accuracy: 0.4351 - val_loss: 1.3082 - val_accuracy: 0.5267
# Epoch 3/50
# 188/188 [==============================] - 15s 80ms/step - loss: 1.3838 - accuracy: 0.4967 - val_loss: 1.2984 - val_accuracy: 0.5287
# Epoch 4/50
# 188/188 [==============================] - 17s 88ms/step - loss: 1.2654 - accuracy: 0.5411 - val_loss: 1.0902 - val_accuracy: 0.6187
# Epoch 5/50
# 188/188 [==============================] - 14s 77ms/step - loss: 1.2059 - accuracy: 0.5668 - val_loss: 1.2312 - val_accuracy: 0.5507
# Epoch 6/50
# 188/188 [==============================] - 15s 81ms/step - loss: 1.1518 - accuracy: 0.5895 - val_loss: 1.3582 - val_accuracy: 0.5187
# Epoch 7/50
# 188/188 [==============================] - 14s 77ms/step - loss: 1.1074 - accuracy: 0.6036 - val_loss: 1.0028 - val_accuracy: 0.6440
# Epoch 8/50
# 188/188 [==============================] - 16s 88ms/step - loss: 1.0926 - accuracy: 0.6098 - val_loss: 0.9966 - val_accuracy: 0.6487
# Epoch 9/50
# 188/188 [==============================] - 15s 81ms/step - loss: 1.0522 - accuracy: 0.6231 - val_loss: 1.0358 - val_accuracy: 0.6247
# Epoch 10/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.9960 - accuracy: 0.6403 - val_loss: 1.1573 - val_accuracy: 0.5847
# Epoch 11/50
# 188/188 [==============================] - 17s 92ms/step - loss: 0.9816 - accuracy: 0.6457 - val_loss: 0.9079 - val_accuracy: 0.6873
# Epoch 12/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.9509 - accuracy: 0.6633 - val_loss: 1.1247 - val_accuracy: 0.6020
# Epoch 13/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.9422 - accuracy: 0.6628 - val_loss: 0.8286 - val_accuracy: 0.7160
# Epoch 14/50
# 188/188 [==============================] - 17s 90ms/step - loss: 0.9204 - accuracy: 0.6733 - val_loss: 1.1024 - val_accuracy: 0.6033
# Epoch 15/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.8994 - accuracy: 0.6763 - val_loss: 1.0082 - val_accuracy: 0.6693
# Epoch 16/50
# 188/188 [==============================] - 15s 77ms/step - loss: 0.8788 - accuracy: 0.6855 - val_loss: 0.9358 - val_accuracy: 0.6620
# Epoch 17/50
# 188/188 [==============================] - 15s 81ms/step - loss: 0.8500 - accuracy: 0.6952 - val_loss: 0.8379 - val_accuracy: 0.7113
# Epoch 18/50
# 188/188 [==============================] - 17s 92ms/step - loss: 0.8382 - accuracy: 0.7022 - val_loss: 0.8872 - val_accuracy: 0.6920
# Epoch 19/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.8251 - accuracy: 0.7097 - val_loss: 0.7587 - val_accuracy: 0.7267
# Epoch 20/50
# 188/188 [==============================] - 15s 77ms/step - loss: 0.8140 - accuracy: 0.7157 - val_loss: 0.7345 - val_accuracy: 0.7487
# Epoch 21/50
# 188/188 [==============================] - 21s 113ms/step - loss: 0.8023 - accuracy: 0.7194 - val_loss: 1.0846 - val_accuracy: 0.6320
# Epoch 22/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.7732 - accuracy: 0.7267 - val_loss: 0.8082 - val_accuracy: 0.7367
# Epoch 23/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.7831 - accuracy: 0.7270 - val_loss: 0.7894 - val_accuracy: 0.7367
# Epoch 24/50
# 188/188 [==============================] - 17s 93ms/step - loss: 0.7576 - accuracy: 0.7294 - val_loss: 0.7233 - val_accuracy: 0.7493
# Epoch 25/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.7537 - accuracy: 0.7360 - val_loss: 0.7837 - val_accuracy: 0.7227
# Epoch 26/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.7365 - accuracy: 0.7322 - val_loss: 0.6805 - val_accuracy: 0.7740
# Epoch 27/50
# 188/188 [==============================] - 16s 84ms/step - loss: 0.7328 - accuracy: 0.7402 - val_loss: 0.6795 - val_accuracy: 0.7600
# Epoch 28/50
# 188/188 [==============================] - 15s 82ms/step - loss: 0.7290 - accuracy: 0.7467 - val_loss: 0.8025 - val_accuracy: 0.7200
# Epoch 29/50
# 188/188 [==============================] - 15s 78ms/step - loss: 0.7132 - accuracy: 0.7492 - val_loss: 0.8236 - val_accuracy: 0.7080
# Epoch 30/50
# 188/188 [==============================] - 15s 77ms/step - loss: 0.7120 - accuracy: 0.7470 - val_loss: 0.6972 - val_accuracy: 0.7653
# Epoch 31/50
# 188/188 [==============================] - 18s 95ms/step - loss: 0.7006 - accuracy: 0.7540 - val_loss: 0.7500 - val_accuracy: 0.7353
# Epoch 32/50
# 188/188 [==============================] - 15s 78ms/step - loss: 0.6769 - accuracy: 0.7609 - val_loss: 0.7110 - val_accuracy: 0.7580
# Epoch 33/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.6743 - accuracy: 0.7679 - val_loss: 0.7460 - val_accuracy: 0.7327
# Epoch 34/50
# 188/188 [==============================] - 17s 89ms/step - loss: 0.6698 - accuracy: 0.7667 - val_loss: 0.6919 - val_accuracy: 0.7573
# Epoch 35/50
# 188/188 [==============================] - 15s 77ms/step - loss: 0.6767 - accuracy: 0.7582 - val_loss: 0.6800 - val_accuracy: 0.7560
# Epoch 36/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.6625 - accuracy: 0.7617 - val_loss: 0.6480 - val_accuracy: 0.7727
# Epoch 37/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.6509 - accuracy: 0.7697 - val_loss: 0.7066 - val_accuracy: 0.7527
# Epoch 38/50
# 188/188 [==============================] - 17s 90ms/step - loss: 0.6381 - accuracy: 0.7716 - val_loss: 0.6334 - val_accuracy: 0.7927
# Epoch 39/50
# 188/188 [==============================] - 14s 77ms/step - loss: 0.6632 - accuracy: 0.7647 - val_loss: 0.6719 - val_accuracy: 0.7847
# Epoch 40/50
# 188/188 [==============================] - 15s 77ms/step - loss: 0.6347 - accuracy: 0.7756 - val_loss: 0.6485 - val_accuracy: 0.7760
# Epoch 41/50
# 188/188 [==============================] - 17s 92ms/step - loss: 0.6306 - accuracy: 0.7766 - val_loss: 0.6850 - val_accuracy: 0.7640
# Epoch 42/50
# 188/188 [==============================] - 15s 82ms/step - loss: 0.6264 - accuracy: 0.7786 - val_loss: 0.6245 - val_accuracy: 0.7900
# Epoch 43/50
# 188/188 [==============================] - 15s 81ms/step - loss: 0.6244 - accuracy: 0.7811 - val_loss: 0.6493 - val_accuracy: 0.7813
# Epoch 44/50
# 188/188 [==============================] - 17s 92ms/step - loss: 0.6127 - accuracy: 0.7864 - val_loss: 0.6172 - val_accuracy: 0.8007
# Epoch 45/50
# 188/188 [==============================] - 15s 81ms/step - loss: 0.5902 - accuracy: 0.7909 - val_loss: 0.6182 - val_accuracy: 0.7940
# Epoch 46/50
# 188/188 [==============================] - 15s 81ms/step - loss: 0.6011 - accuracy: 0.7826 - val_loss: 0.7263 - val_accuracy: 0.7547
# Epoch 47/50
# 188/188 [==============================] - 16s 86ms/step - loss: 0.5844 - accuracy: 0.7912 - val_loss: 0.6482 - val_accuracy: 0.7793
# Epoch 48/50
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5929 - accuracy: 0.7997 - val_loss: 0.7580 - val_accuracy: 0.7433
# Epoch 49/50
# 188/188 [==============================] - 15s 77ms/step - loss: 0.5911 - accuracy: 0.7952 - val_loss: 0.6280 - val_accuracy: 0.7887
# Epoch 50/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.5723 - accuracy: 0.8024 - val_loss: 0.6584 - val_accuracy: 0.7787
# 79/79 - 1s - loss: 0.6662 - accuracy: 0.7855 - 1s/epoch - 14ms/step
#
# Test accuracy: 0.7855141758918762
# 1/1 [==============================] - 0s 168ms/step
# Target: 8, Predicted label: [6]

# %%
print("Real Genre:", y_to_predict)
# Out:
# Real Genre: 8

# %%
# add a dimension to input data for sample - model.predict() expects a 4d array in this case
X_to_predict = X_to_predict[np.newaxis, ...] # array shape (1, 130, 13, 1)

# %%
X_to_predict.shape
# Out:
# (1, 130, 13, 1)

# %%
# perform prediction
prediction = model.predict(X_to_predict)
# Out:
# 1/1 [==============================] - 0s 37ms/step

# %%
# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", int(predicted_index))
# Out:
# Predicted Genre: 6

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[50]
y_to_predict = y_test[50]

print("Real Genre:", y_to_predict)

X_to_predict = X_to_predict[np.newaxis, ...]

prediction = model.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", int(predicted_index))
# Out:
# Real Genre: 6
# 1/1 [==============================] - 0s 25ms/step
# Predicted Genre: 6

# %%
len(X_test)
# Out:
# 2499

# %%
import random

# %%
for n in range(10):
  i = random.randint(0,len(X_test))
  # pick a sample to predict from the test set
  X_to_predict = X_test[i]
  y_to_predict = y_test[i]

  print("\nReal Genre:", y_to_predict)

  X_to_predict = X_to_predict[np.newaxis, ...]

  prediction = model.predict(X_to_predict)

  # get index with max value
  predicted_index = np.argmax(prediction, axis=1)

  print("Predicted Genre:", int(predicted_index))
# Out:
# Real Genre: 3
# 1/1 [==============================] - 0s 24ms/step
# Predicted Genre: 3
#
# Real Genre: 9
# 1/1 [==============================] - 0s 29ms/step
# Predicted Genre: 9
#
# Real Genre: 0
# 1/1 [==============================] - 0s 29ms/step
# Predicted Genre: 4
#
# Real Genre: 5
# 1/1 [==============================] - 0s 26ms/step
# Predicted Genre: 5
#
# Real Genre: 3
# 1/1 [==============================] - 0s 29ms/step
# Predicted Genre: 3
#
# Real Genre: 2
# 1/1 [==============================] - 0s 31ms/step
# Predicted Genre: 2
#
# Real Genre: 8
# 1/1 [==============================] - 0s 24ms/step
# Predicted Genre: 6
#
# Real Genre: 9
# 1/1 [==============================] - 0s 24ms/step
# Predicted Genre: 9
#
# Real Genre: 0
# 1/1 [==============================] - 0s 35ms/step
# Predicted Genre: 1
#
# Real Genre: 4
# 1/1 [==============================] - 0s 26ms/step
# Predicted Genre: 4

# %%
# Audio files pre-processing
def process_input(audio_file, track_duration):

  SAMPLE_RATE = 22050
  NUM_MFCC = 13
  N_FTT=2048
  HOP_LENGTH=512
  TRACK_DURATION = track_duration # measured in seconds
  SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION
  NUM_SEGMENTS = 10

  samples_per_segment = int(SAMPLES_PER_TRACK / NUM_SEGMENTS)
  num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / HOP_LENGTH)

  signal, sample_rate = librosa.load(audio_file, sr=SAMPLE_RATE)
  
  for d in range(10):

    # calculate start and finish sample for current segment
    start = samples_per_segment * d
    finish = start + samples_per_segment

    # extract mfcc
    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=NUM_MFCC, n_fft=N_FTT, hop_length=HOP_LENGTH)
    mfcc = mfcc.T

    return mfcc

# %%
genre_dict = {0:"hiphop",1:"country",2:"jazz",3:"classical",4:"metal",5:"pop",6:"rock",7:"blues",8:"reggae",9:"disco"}

# %%
new_input_mfcc = process_input("/content/Little Howlin' Wolf - Last Double Eagle.mp3", 30)

# %%
type(new_input_mfcc)
# Out:
# numpy.ndarray

# %%
new_input_mfcc.shape
# Out:
# (130, 13)

# %%
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape
# Out:
# (1, 130, 13, 1)

# %%
prediction = model.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 40ms/step
# Predicted Genre: jazz

# %%
new_input_mfcc = process_input("/content/Filmy Ghost (Sábila Orbe) - Dark Confessions IV.mp3", 30)
type(new_input_mfcc)
new_input_mfcc.shape
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape

prediction = model.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Predicted Genre: classical

# %%
new_input_mfcc = process_input("/content/Here Comes A Big Black Cloud!! - Death March.mp3", 30)
type(new_input_mfcc)
new_input_mfcc.shape
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape

prediction = model.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Predicted Genre: jazz

# %%
new_input_mfcc = process_input("/content/demolition_man_proud_music_preview.mp3", 30)
type(new_input_mfcc)
new_input_mfcc.shape
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape

prediction = model.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 39ms/step
# Predicted Genre: metal

# %%
new_input_mfcc = process_input("/content/Kimiko Ishizaka - Variatio 3 a 1 Clav. Canone all'Unisuono.mp3", 30)
type(new_input_mfcc)
new_input_mfcc.shape
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape

prediction = model.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 45ms/step
# Predicted Genre: classical

# %%
new_input_mfcc = process_input("/content/Advent Chamber Orchestra - Handel - Entrance to the Queen of Sheba for Two Oboes, Strings, and Continuo allegro.mp3", 30)
type(new_input_mfcc)
new_input_mfcc.shape
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape

prediction = model.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 55ms/step
# Predicted Genre: blues

# %%
new_input_mfcc = process_input("/content/metal-dark-matter-111451.mp3", 30)
type(new_input_mfcc)
new_input_mfcc.shape
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape

prediction = model.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Predicted Genre: classical

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
